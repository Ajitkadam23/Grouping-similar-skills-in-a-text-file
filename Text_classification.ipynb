# %%
##I have used a dataset which is available at https://data.world/peopledatalabs/similar-skills-28935-unique-skills for training
#in LDA model
# I used  coherence scores method to determine optimum number of topics/groups in the List of skills for this I took
# help from this site= https://www.datacamp.com/community/tutorials/discovering-hidden-topics-python
#Peak of the graph was at 32 so I choose 32 groups
#I used first I tried to solve this task using K Means and TF-IDF technique but It  was not giving good result 
#large amount of the skills were grouped into a single clusters 
#So I used LDA technique using gensim library.

def compute_coherence_values(dictionary, doc_term_matrix, doc_clean, stop, start=2, step=3):
   
    coherence_values = []
    model_list = []
    for num_topics in range(start, stop, step):
        model = LsiModel(doc_term_matrix, num_topics=number_of_topics, id2word = dictionary)  # train model
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=doc_clean, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
    return model_list, coherence_values



def plot_graph(doc_clean,start, stop, step):
    dictionary,doc_term_matrix=prepare_corpus(doc_clean)
    model_list, coherence_values = compute_coherence_values(dictionary, doc_term_matrix,doc_clean,
                                                            stop, start, step)
    # Show graph
    x = range(start, stop, step)
    plt.plot(x, coherence_values)
    plt.xlabel("Number of Topics")
    plt.ylabel("Coherence score")
    plt.legend(("coherence_values"), loc='best')
    plt.show()


words=10
document_list,titles=load_data("/home/ajit/Desktop/Text_ML/","similarskills.csv")
clean_text=preprocess_data(document_list)    
    

start,stop,step=2,30,1
plot_graph(clean_text,start,stop,step)

# %%
import pandas as pd
data = pd.read_csv('/home/ajit/Desktop/Text_ML/similarskills.csv', error_bad_lines=False);
data_text = data[['headline_text']]
data_text['index'] = data_text.index
documents = data_text


print(len(documents))
print(documents[:5])
from nltk.stem.porter import *
stemmer = PorterStemmer()

# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer

from nltk.stem.porter import *
import numpy as np
np.random.seed(2018)
import nltk

# %%
def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))
def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
    return result

# %%
doc_sample = documents[documents['index'] == 4310].values[0][0]
print('original document: ')
words = []
for word in doc_sample.split(' '):
    words.append(word)

print(preprocess(doc_sample))

# %%
processed_docs = documents['headline_text'].map(preprocess)
processed_docs[:10]

# %%
dictionary = gensim.corpora.Dictionary(processed_docs)
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 10:
        break

# %%
dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]

from gensim import corpora, models
tfidf = models.TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]
from pprint import pprint
for doc in corpus_tfidf:
    pprint(doc)
    break

# %%
lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics=32, id2word=dictionary, passes=2, workers=2)

# %%
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))

# %%
from collections import defaultdict
d = defaultdict(list)
d={"g1":[],"g2":[],"g3":[],"g4":[],"g5":[],"g6":[],"g7":[],"g8":[],"g9":[],"g10":[],"g11":[],"g12":[],"g13":[],"g14":[],"g15":[],"g16":[],"g17":[],"g18":[] ,"g19":[],"g20":[],"g21":[],"g22":[],"g23":[],"g24":[],"g25":[],"g26":[],"g27":[],"g28":[],"g29":[],"g30":[],"g31":[],"g32":[]}
import csv

with open('/home/ajit/Downloads/ListOfSkills.csv','r') as readf:
    with open('/home/ajit/Desktop/Text_ML/similarskills_LDA_prediction.csv','w') as writef:
        fwrite=csv.writer(writef)
        fread=csv.reader(readf)
        for row in fread:
            unseen_document = row[0]
            print(row[0])
            bow_vector = dictionary.doc2bow(preprocess(unseen_document))
            arr=[]
            arr.append(row[0])
            print(arr)
            for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
               
                if index==0:
                    d["g1"].append(row[0])
                if index==1:
                    d["g2"].append(row[0])
                if index==2:
                    d["g3"].append(row[0])
                if index==3:
                    d["g4"].append(row[0])
                if index==4:
                    d["g5"].append(row[0])
                if index==5:
                    d["g6"].append(row[0])
                if index==6:
                    d["g7"].append(row[0])
                if index==7:
                    d["g8"].append(row[0])
                if index==8:
                    d["g9"].append(row[0])
                if index==9:
                    d["g10"].append(row[0])
                if index==10:
                    d["g11"].append(row[0])
                if index==11:
                    d["g12"].append(row[0])
                if index==12:
                    d["g13"].append(row[0])
                if index==13:
                    d["g14"].append(row[0])
                if index==14:
                    d["g15"].append(row[0])
                if index==15:
                    d["g16"].append(row[0])
                if index==16:
                    d["g17"].append(row[0])
                if index==17:
                    d["g18"].append(row[0])
                if index==18:
                    d["g19"].append(row[0])
                if index==19:
                    d["g20"].append(row[0])
                if index==20:
                    d["g21"].append(row[0])
                if index==21:
                    d["g22"].append(row[0])
                if index==22:
                    d["g23"].append(row[0])
                if index==23:
                    d["g24"].append(row[0])
                if index==24:
                    d["g25"].append(row[0])
                if index==25:
                    d["g26"].append(row[0])
                if index==26:
                    d["g27"].append(row[0])
                if index==27:
                    d["g28"].append(row[0])
                if index==28:
                    d["g29"].append(row[0])
                if index==29:
                    d["g30"].append(row[0])
                if index==30:
                    d["g31"].append(row[0])
                if index==31:
                    d["g32"].append(row[0])
        
                arr.append(index)
#                 print(arr)
                break
# print(d)
        for key, value in d.items():
               fwrite.writerow([key, value])
